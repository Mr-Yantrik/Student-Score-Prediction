# %%
import joblib
import pandas as pd

# Load trained model
model = joblib.load("model/student_score_model.pkl")

# Example student data (same order as dataset columns)
new_student = pd.DataFrame([{
    'Hours_Studied': 6,
    'Attendance': 85,
    'Parental_Involvement': 2,
    'Access_to_Resources': 2,
    'Extracurricular_Activities': 1,
    'Sleep_Hours': 7,
    'Previous_Scores': 70,
    'Motivation_Level': 2,
    'Internet_Access': 1,
    'Tutoring_Sessions': 2,
    'Family_Income': 1,
    'Teacher_Quality': 2,
    'School_Type': 1,
    'Peer_Influence': 2,
    'Physical_Activity': 3,
    'Learning_Disabilities': 0,
    'Parental_Education_Level': 2,
    'Distance_from_Home': 1,
    'Gender': 1
}])

# Predict
predicted_score = model.predict(new_student)

print("🎯 Predicted Exam Score:", predicted_score[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 # Load trained model
# ----> 5 model = joblib.load("model/student_score_model.pkl")
#       7 # Example student data (same order as dataset columns)
#       8 new_student = pd.DataFrame([{
#       9     'Hours_Studied': 6,
#      10     'Attendance': 85,
#    (...)     27     'Gender': 1
#      28 }])
#
# File ~/miniconda3/lib/python3.13/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
# ...
